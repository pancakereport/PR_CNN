# %%
# %run "../keras-retinanet/keras_retinanet/bin/train.py" --weights ../keras-retinanet/Models/resnet50_coco_best_v2.1.0.h5 \
--batch-size 2 --steps 500 --epochs 30 \
--snapshot-path ../Data/Elephant_Snapshot \
--random-transform \
--config elephant_config.ini \
csv ../Images/Elephant_Seals_Full_Data/elephant_train_annotations.csv ../Images/Elephant_Seals_Full_Data/elephant_classes.csv \
--val-annotations ../Images/Elephant_Seals_Full_Data/elephant_val_annotations.csv
# Out:
# pre parse
# post arg
# post generator
# Creating model, this may take a second...
# WARNING:tensorflow:Skipping loading of weights for layer classification_submodel due to mismatch in shape ((3, 3, 256, 27) vs (3, 3, 256, 720)).
# WARNING:tensorflow:Skipping loading of weights for layer classification_submodel due to mismatch in shape ((27,) vs (720,)).
# model summary here
# start training
# Epoch 1/30
# 298/500 [================>.............] - ETA: 1:07:54 - loss: 2.7444 - regression_loss: 1.9417 - classification_loss: 0.8027WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 15000 batches). You may need to use the repeat() function when building your dataset.
# Running network: 100% (50 of 50) |#######| Elapsed Time: 0:05:54 Time:  0:05:54
# Parsing annotations: 100% (50 of 50) |###| Elapsed Time: 0:00:00 Time:  0:00:00
# ...

# %%
# %run "../keras-retinanet/keras_retinanet/bin/train.py" --weights ../Data/Elephant_Snapshot/resnet50_csv_01_initial.h5 \
--batch-size 2 --steps 280 --epochs 30 \
--snapshot-path ../Data/Elephant_Snapshot \
--random-transform \
--config elephant_config.ini \
csv ../Images/Elephant_Seals_Full_Data/elephant_train_annotations.csv ../Images/Elephant_Seals_Full_Data/elephant_classes.csv \
--val-annotations ../Images/Elephant_Seals_Full_Data/elephant_val_annotations.csv
# Out:
# pre parse
# post arg
# post generator
# Creating model, this may take a second...
# model summary here
# start training
# Epoch 1/30
# 280/280 [==============================] - ETA: 0s - loss: 2.1711 - regression_loss: 1.7124 - classification_loss: 0.4587
# Running network: 100% (50 of 50) |#######| Elapsed Time: 0:10:24 Time:  0:10:24
# Parsing annotations: 100% (50 of 50) |###| Elapsed Time: 0:00:00 Time:  0:00:00
# 234 instances of class cow with average precision: 0.1606
# 54 instances of class bull with average precision: 0.3788
# 394 instances of class pup with average precision: 0.1433
# mAP: 0.2276
#
# Epoch 00001: saving model to ../Data/Elephant_Snapshot\resnet50_csv_01.h5
# 280/280 [==============================] - 10525s 38s/step - loss: 2.1711 - regression_loss: 1.7124 - classification_loss: 0.4587
# Epoch 2/30
# 280/280 [==============================] - ETA: 0s - loss: 2.0888 - regression_loss: 1.6641 - classification_loss: 0.4246
# ...

# %%
###### first arg is the model to convert, second is the path to save the model to
# %run "../keras-retinanet/keras_retinanet/bin/convert_model.py" --config elephant_config.ini ../Data/Elephant_Snapshot/resnet50_csv_17.h5 ../Data/final_model_elephant_seal17.h5

# %%
# %run "../keras-retinanet/keras_retinanet/bin/convert_model.py" --config elephant_config.ini ../Data/Elephant_Snapshot/resnet50_csv_13.h5 ../Data/final_model_elephant_seal13.h5

# %%
#evaluate the model on the test set
#first arg is test annotations, second is classes, third is (converted) model
#classes must be in same dir as the tiled images


##TEST
# %run "../keras-retinanet/keras_retinanet/bin/evaluate.py" csv ../Images/Elephant_Seals_Beach_Only/elephant_test_annotations.csv ../Data/elephant_seal_correct_annotations/elephant_classes.csv ../Data/final_model_elephant_seal17.h5
# Out:
# Loading model, this may take a second...
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Running network: 100% (74 of 74) |#######| Elapsed Time: 0:06:44 Time:  0:06:44
# Parsing annotations: 100% (74 of 74) |###| Elapsed Time: 0:00:00 Time:  0:00:00
# 368 instances of class cow with average precision: 0.3206
# 72 instances of class bull with average precision: 0.4459
# 688 instances of class pup with average precision: 0.2513
# Inference time for 74 images: 5.4182
# mAP using the weighted average of precisions among classes: 0.2863
# mAP: 0.3392

# %%
#evaluate the model on the val set
# %run "../keras-retinanet/keras_retinanet/bin/evaluate.py" csv ../Images/Elephant_Seals_Beach_Only/elephant_val_annotations.csv ../Data/elephant_seal_correct_annotations/elephant_classes.csv ../Data/final_model_elephant_seal17.h5
# Out:
# Loading model, this may take a second...
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Running network: 100% (59 of 59) |#######| Elapsed Time: 0:04:41 Time:  0:04:41
# Parsing annotations: 100% (59 of 59) |###| Elapsed Time: 0:00:00 Time:  0:00:00
# 340 instances of class cow with average precision: 0.3513
# 50 instances of class bull with average precision: 0.3485
# 658 instances of class pup with average precision: 0.2665
# Inference time for 59 images: 4.7330
# mAP using the weighted average of precisions among classes: 0.2980
# mAP: 0.3221

# %%
# %run "../keras-retinanet/keras_retinanet/bin/evaluate.py" csv ../Images/Elephant_Seals_Beach_Only/elephant_test_annotations.csv ../Data/elephant_seal_correct_annotations/elephant_classes.csv ../Data/final_model_elephant_seal13.h5
# Out:
# Loading model, this may take a second...
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Running network: 100% (74 of 74) |#######| Elapsed Time: 0:06:16 Time:  0:06:16
# Parsing annotations: 100% (74 of 74) |###| Elapsed Time: 0:00:00 Time:  0:00:00
# 368 instances of class cow with average precision: 0.2956
# 72 instances of class bull with average precision: 0.4202
# 688 instances of class pup with average precision: 0.2412
# Inference time for 74 images: 5.0521
# mAP using the weighted average of precisions among classes: 0.2704
# mAP: 0.3190

# %%
# %run "../keras-retinanet/keras_retinanet/bin/evaluate.py" csv ../Images/Elephant_Seals_Beach_Only/elephant_val_annotations.csv ../Data/elephant_seal_correct_annotations/elephant_classes.csv ../Data/final_model_elephant_seal13.h5
# Out:
# Loading model, this may take a second...
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Running network: 100% (59 of 59) |#######| Elapsed Time: 0:04:45 Time:  0:04:45
# Parsing annotations: 100% (59 of 59) |###| Elapsed Time: 0:00:00 Time:  0:00:00
# 340 instances of class cow with average precision: 0.3222
# 50 instances of class bull with average precision: 0.3287
# 658 instances of class pup with average precision: 0.2600
# Inference time for 59 images: 4.7893
# mAP using the weighted average of precisions among classes: 0.2835
# mAP: 0.3036

# %%
# %matplotlib inline

# %reload_ext autoreload
# %autoreload 2

import keras

from keras_retinanet.models import retinanet
from keras_retinanet import models
from keras_retinanet.utils.image import read_image_bgr, preprocess_image, resize_image
from keras_retinanet.utils.visualization import draw_box, draw_caption
from keras_retinanet.utils.colors import label_color


import matplotlib.pyplot as plt
import cv2
import sys
import os
import numpy as np
import time
import json
from random import shuffle

import tensorflow as tf

def get_session():
    config = tf.compat.v1.ConfigProto()
    config.gpu_options.allow_growth = True
    return tf.compat.v1.Session(config=config)

tf.compat.v1.keras.backend.set_session(get_session())

# %%
sys.path.insert(0, '../keras-retinanet/keras_retinanet')
from utils.gpu import setup_gpu

# use this to change which GPU to use
gpu = '1'

# set the modified tf session as backend in keras
setup_gpu(gpu)

#tf.config.threading.set_inter_op_parallelism_threads(20)

# %%
model_path = '../Data/final_model_elephant_seal17_best.h5'

#print(model_path)

model = models.load_model(model_path, backbone_name='resnet50')

#print(model.summary())

labels_to_names = {"0":"cow","1":"bull","2":"pup"}
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
import os
image_dir = "../Images/Elephant_Seals_Beach_Only/"

image_list = []
for root, dirs, files in os.walk(image_dir):
    for filename in files:
        if filename.lower().endswith(('.png')):
            image_list.append(image_dir + filename)
print(len(image_list))
# Out:
# 1741

# %%
visualize = True
min_score = 0.5

detections = {}

total_time = 0

count = 0
detection_iterations = 10
shuffle(image_list)

for image_path in image_list: 
    if count > detection_iterations:
        break
    else: 
        count +=1
    
    image = read_image_bgr(image_path)
    
    if visualize:
        draw = image.copy()
        draw = cv2.cvtColor(draw, cv2.COLOR_BGR2RGB)
        
    image = preprocess_image(image)
    image, scale = resize_image(image)
    
    start = time.time()
    boxes, scores, labels = model.predict_on_batch(np.expand_dims(image, axis=0))
    total_time += time.time() - start 
    
    boxes /= scale
    if any(score >= min_score for score in scores [0]):
        detections[image_path] = []
    
    for box, score, label in zip(boxes[0], scores[0], labels[0]):
        if score < min_score:
            break
        
        b = box.astype(int)
        detections[image_path].append({"box" : b, "label" : label, "score" : score})
        
        if visualize: 
            color = label_color(label)
            
            draw_box(draw, b, color=color)
            
            caption = "{} {:.3f}".format(labels_to_names[label], score)
            draw_caption(draw, b, caption)
            
    if any(score >= min_score for score in scores[0]):
        if visualize:
            plt.figure(figsize=(15, 15))
            plt.axis('off')
            plt.imshow(draw)
            plt.show()
            
print("Finished, time per image:", total_time/len(image_list))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-74740c7321bf> in <module>
#      26
#      27     start = time.time()
# ---> 28     boxes, scores, labels = model.predict_on_batch(np.expand_dims(image, axis=0))
#      29     total_time += time.time() - start
#      30
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in predict_on_batch(self, x)
#    1786       iterator = data_adapter.single_batch_iterator(self.distribute_strategy, x)
#    1787       predict_function = self.make_predict_function()
# -> 1788       outputs = predict_function(iterator)
#    1789     return tf_utils.to_numpy_or_python_type(outputs)
#    1790
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# ...

# %%
min_score = 0.5

detections = {}

cows = 0
pups = 0
bulls = 0

total_time = 0

for image_path in image_list:
    
    image = read_image_bgr(image_path)
          
    image = preprocess_image(image)
    image, scale = resize_image(image)
    
    start = time.time()
    boxes, scores, labels = model.predict_on_batch(np.expand_dims(image, axis=0))
    total_time += time.time() - start
    
    boxes /= scale  
        
    if any(score >= min_score for score in scores[0]):
        detections[image_path] = []
        
    for box, score, label in zip(boxes[0], scores[0], labels[0]):
        if score < min_score:
            break
        
        b = box.astype(int)    
        detections[image_path].append({"box" : b, "label" : label, "score" : score})
        if label == 0:
            cows += 1
        elif label == 1:
            bulls += 1
        elif label == 2:
            pups += 1
        
            
print("Finished, time per image:", total_time/len(image_list))

# %%
class MyEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        elif isinstance(obj, np.floating):
            return float(obj)
        elif isinstance(obj, np.ndarray):
            return obj.tolist()
        else:
            return super(MyEncoder, self).default(obj)

# %%
with open('../Test_Output/detections.json', 'w') as fp:
    json.dump(detections, fp, cls=MyEncoder)

# %%
print(len(detections))
print("cows:", cows)
print("bulls:", bulls)
print("pups:", pups)
